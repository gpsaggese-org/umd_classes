# %% [markdown]
# ## Imports

# %%
# %load_ext autoreload
# %autoreload 2

import logging
import os

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import helpers.hmodule as hmodule

# hmodule.install_module_if_not_present(
#     "networkx",
#     use_activate=True,
# )
# hmodule.install_module_if_not_present(
#     "pgmpy",
#     use_activate=True,
# )

# %%
import helpers.hnotebook as hnotebo

import msml610_utils as ut
import L08_04_05_causal_inference_utils as mtl0cire05

ut.config_notebook()

# Initialize logger.
logging.basicConfig(level=logging.INFO)
_LOG = logging.getLogger(__name__)
hnotebo.set_logger_to_print(_LOG)
hnotebo.set_all_loggers_to_print()
# Out:
# pymc is not installed
# arviz is not installed
# preliz is not installed
# sns is not installed
# Python 3.12.13
# Linux 3f3aef6a9c0f 6.12.67-linuxkit #1 SMP Sun Jan 25 02:26:28 UTC 2026 aarch64 GNU/Linux

# %%
dir_name = "L08_data"
#!ls $dir_name

out_dir_name = "figures/"

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(os.path.join(dir_name, "management_training.csv"))
import helpers.hpandas_display as hpanddis

hpanddis.display_df(df)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>departament_id</th>
#       <th>intervention</th>
#       <th>engagement_score</th>
#       <th>tenure</th>
#       <th>n_of_reports</th>
#       <th>gender</th>
#       <th>role</th>
#       <th>last_engagement_score</th>
#       <th>department_score</th>
#       <th>department_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>76</td>
#       <td>1</td>
#       <td>0.277359</td>
#       <td>6</td>
#       <td>4</td>
#       <td>2</td>
#       <td>4</td>
#       <td>0.614261</td>
#       <td>0.224077</td>
#       <td>843</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>76</td>
#       <td>1</td>
#       <td>-0.449646</td>
#       <td>4</td>
#       <td>8</td>
#       <td>2</td>
#       <td>4</td>
#       <td>0.069636</td>
#       <td>0.224077</td>
#       <td>843</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>10389</th>
#       <td>1</td>
#       <td>0</td>
#       <td>-0.396297</td>
#       <td>5</td>
#       <td>4</td>
#       <td>1</td>
#       <td>3</td>
#       <td>-1.277477</td>
#       <td>1.005063</td>
#       <td>323</td>
#     </tr>
#     <tr>
#       <th>10390</th>
#       <td>1</td>
#       <td>1</td>
#       <td>0.47897</td>
#       <td>5</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>-1.584552</td>
#       <td>1.005063</td>
#       <td>323</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The dataset contains information on managers with the following variables:
#
# - **intervention**: Binary treatment indicator (1 = received training, 0 =
#   control)
# - **engagement_score**: Primary outcome—average standardized engagement score of
#   manager's employees
# - **department_id**: Unique department identifier
# - **tenure**: Years the manager has been with the company
# - **n_of_reports**: Number of direct reports the manager has
# - **gender**: Manager's identified gender (categorical)
# - **role**: Job category within the company (categorical)
# - **department_size**: Number of employees in the department
# - **department_score**: Average engagement score in the department
# - **last_engagement_score**: Previous period's engagement score for the manager

# %%
import helpers.hpandas_stats as hpanstat

show_distributions = True
show_correlations = True

hpanstat.explore_dataframe(df, show_distributions=show_distributions, show_correlations=show_correlations)
# Out:
# INFO:helpers.hpandas_stats:stats_df=
# WARNING: Can't find pytz: continuing
#                        num_rows zeros [%] nans [%] infs [%] valid [%]  \
# departament_id            10391       0.0      0.0      0.0     100.0
# intervention              10391      46.0      0.0      0.0      54.0
# engagement_score          10391       0.0      0.0      0.0     100.0
# tenure                    10391       0.0      0.0      0.0     100.0
# n_of_reports              10391       0.0      0.0      0.0     100.0
# gender                    10391       0.0      0.0      0.0     100.0
# role                      10391      8.13      0.0      0.0     91.87
# last_engagement_score     10391       0.0      0.0      0.0     100.0
# department_score          10391       0.0      0.0      0.0     100.0
# department_size           10391       0.0      0.0      0.0     100.0
#
#                        num_unique unique [%]
# departament_id                 76       0.73
# intervention                    2       0.02
# engagement_score            10391      100.0
# tenure                          7       0.07
# n_of_reports                    8       0.08
# gender                          2       0.02
# role                            5       0.05
# last_engagement_score       10391      100.0
# department_score               76       0.73
# department_size                72       0.69
# INFO:helpers.hpandas_stats:Univariate distributions:
# INFO:helpers.hpandas_stats:Correlation matrix:
# <style type="text/css">
# #T_a8deb_row0_col0, #T_a8deb_row1_col1, #T_a8deb_row2_col2, #T_a8deb_row3_col3, #T_a8deb_row4_col4, #T_a8deb_row5_col5, #T_a8deb_row6_col6, #T_a8deb_row7_col7, #T_a8deb_row8_col8, #T_a8deb_row9_col9 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_a8deb_row0_col1, #T_a8deb_row1_col0, #T_a8deb_row1_col4, #T_a8deb_row4_col1, #T_a8deb_row5_col7, #T_a8deb_row7_col5 {
#   background-color: #e38b9d;
#   color: #f1f1f1;
# }
# #T_a8deb_row0_col2, #T_a8deb_row2_col0 {
#   background-color: #e0748a;
#   color: #f1f1f1;
# }
# #T_a8deb_row0_col3, #T_a8deb_row3_col0, #T_a8deb_row4_col7, #T_a8deb_row7_col4 {
#   background-color: #e494a4;
#   color: #f1f1f1;
# }
# #T_a8deb_row0_col4, #T_a8deb_row4_col0 {
#   background-color: #e69caa;
#   color: #000000;
# }
# #T_a8deb_row0_col5, #T_a8deb_row2_col9, #T_a8deb_row5_col0, #T_a8deb_row5_col8, #T_a8deb_row5_col9, #T_a8deb_row8_col5, #T_a8deb_row9_col2, #T_a8deb_row9_col5 {
#   background-color: #e38d9e;
#   color: #f1f1f1;
# }
# #T_a8deb_row0_col6, #T_a8deb_row6_col0 {
#   background-color: #e9b4be;
#   color: #000000;
# }
# #T_a8deb_row0_col7, #T_a8deb_row4_col9, #T_a8deb_row7_col0, #T_a8deb_row9_col4 {
#   background-color: #e492a3;
#   color: #f1f1f1;
# }
# #T_a8deb_row0_col8, #T_a8deb_row8_col0 {
#   background-color: #e8aeba;
#   color: #000000;
# }
# #T_a8deb_row0_col9, #T_a8deb_row9_col0 {
#   background-color: #eed6db;
#   color: #000000;
# }
# #T_a8deb_row1_col2, #T_a8deb_row2_col1 {
#   background-color: #ecc9d0;
#   color: #000000;
# }
# #T_a8deb_row1_col3, #T_a8deb_row3_col1 {
#   background-color: #ecc5cc;
#   color: #000000;
# }
# #T_a8deb_row1_col5, #T_a8deb_row1_col6, #T_a8deb_row3_col6, #T_a8deb_row5_col1, #T_a8deb_row6_col1, #T_a8deb_row6_col3 {
#   background-color: #e28396;
#   color: #f1f1f1;
# }
# #T_a8deb_row1_col7, #T_a8deb_row7_col1 {
#   background-color: #e8aab6;
#   color: #000000;
# }
# #T_a8deb_row1_col8, #T_a8deb_row8_col1 {
#   background-color: #e0798d;
#   color: #f1f1f1;
# }
# #T_a8deb_row1_col9, #T_a8deb_row9_col1 {
#   background-color: #e69dab;
#   color: #000000;
# }
# #T_a8deb_row2_col3, #T_a8deb_row3_col2 {
#   background-color: #dce3ec;
#   color: #000000;
# }
# #T_a8deb_row2_col4, #T_a8deb_row3_col4, #T_a8deb_row4_col2, #T_a8deb_row4_col3, #T_a8deb_row4_col5, #T_a8deb_row5_col4 {
#   background-color: #e3889a;
#   color: #f1f1f1;
# }
# #T_a8deb_row2_col5, #T_a8deb_row5_col2 {
#   background-color: #dc5e77;
#   color: #f1f1f1;
# }
# #T_a8deb_row2_col6, #T_a8deb_row3_col7, #T_a8deb_row6_col2, #T_a8deb_row7_col3 {
#   background-color: #e59aa9;
#   color: #000000;
# }
# #T_a8deb_row2_col7, #T_a8deb_row2_col8, #T_a8deb_row5_col6, #T_a8deb_row6_col5, #T_a8deb_row7_col2, #T_a8deb_row8_col2 {
#   background-color: #e48e9f;
#   color: #f1f1f1;
# }
# #T_a8deb_row3_col5, #T_a8deb_row5_col3 {
#   background-color: #e17e92;
#   color: #f1f1f1;
# }
# #T_a8deb_row3_col8, #T_a8deb_row4_col8, #T_a8deb_row8_col3, #T_a8deb_row8_col4 {
#   background-color: #e17c90;
#   color: #f1f1f1;
# }
# #T_a8deb_row3_col9, #T_a8deb_row9_col3 {
#   background-color: #e595a5;
#   color: #000000;
# }
# #T_a8deb_row4_col6, #T_a8deb_row6_col4 {
#   background-color: #e28497;
#   color: #f1f1f1;
# }
# #T_a8deb_row6_col7, #T_a8deb_row7_col6 {
#   background-color: #de687f;
#   color: #f1f1f1;
# }
# #T_a8deb_row6_col8, #T_a8deb_row8_col6 {
#   background-color: #e6eaef;
#   color: #000000;
# }
# #T_a8deb_row6_col9, #T_a8deb_row9_col6 {
#   background-color: #eab9c3;
#   color: #000000;
# }
# #T_a8deb_row7_col8, #T_a8deb_row8_col7 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_a8deb_row7_col9, #T_a8deb_row9_col7 {
#   background-color: #efdade;
#   color: #000000;
# }
# #T_a8deb_row8_col9, #T_a8deb_row9_col8 {
#   background-color: #df7288;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a8deb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8deb_level0_col0" class="col_heading level0 col0" >departament_id</th>
#       <th id="T_a8deb_level0_col1" class="col_heading level0 col1" >intervention</th>
#       <th id="T_a8deb_level0_col2" class="col_heading level0 col2" >engagement_score</th>
#       <th id="T_a8deb_level0_col3" class="col_heading level0 col3" >tenure</th>
#       <th id="T_a8deb_level0_col4" class="col_heading level0 col4" >n_of_reports</th>
#       <th id="T_a8deb_level0_col5" class="col_heading level0 col5" >gender</th>
#       <th id="T_a8deb_level0_col6" class="col_heading level0 col6" >role</th>
#       <th id="T_a8deb_level0_col7" class="col_heading level0 col7" >last_engagement_score</th>
#       <th id="T_a8deb_level0_col8" class="col_heading level0 col8" >department_score</th>
#       <th id="T_a8deb_level0_col9" class="col_heading level0 col9" >department_size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8deb_level0_row0" class="row_heading level0 row0" >departament_id</th>
#       <td id="T_a8deb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a8deb_row0_col1" class="data row0 col1" >0.002266</td>
#       <td id="T_a8deb_row0_col2" class="data row0 col2" >-0.078337</td>
#       <td id="T_a8deb_row0_col3" class="data row0 col3" >0.029178</td>
#       <td id="T_a8deb_row0_col4" class="data row0 col4" >0.053808</td>
#       <td id="T_a8deb_row0_col5" class="data row0 col5" >0.006494</td>
#       <td id="T_a8deb_row0_col6" class="data row0 col6" >0.141227</td>
#       <td id="T_a8deb_row0_col7" class="data row0 col7" >0.027869</td>
#       <td id="T_a8deb_row0_col8" class="data row0 col8" >0.121768</td>
#       <td id="T_a8deb_row0_col9" class="data row0 col9" >0.259454</td>
#     </tr>
#     <tr>
#       <th id="T_a8deb_level0_row1" class="row_heading level0 row1" >intervention</th>
#       <td id="T_a8deb_row1_col0" class="data row1 col0" >0.002266</td>
#       <td id="T_a8deb_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a8deb_row1_col2" class="data row1 col2" >0.216614</td>
#       <td id="T_a8deb_row1_col3" class="data row1 col3" >0.199276</td>
#       <td id="T_a8deb_row1_col4" class="data row1 col4" >0.000497</td>
#       <td id="T_a8deb_row1_col5" class="data row1 col5" >-0.031315</td>
#       <td id="T_a8deb_row1_col6" class="data row1 col6" >-0.026555</td>
#       <td id="T_a8deb_row1_col7" class="data row1 col7" >0.104083</td>
#       <td id="T_a8deb_row1_col8" class="data row1 col8" >-0.065904</td>
#       <td id="T_a8deb_row1_col9" class="data row1 col9" >0.063432</td>
#     </tr>
#     <tr>
#       <th id="T_a8deb_level0_row2" class="row_heading level0 row2" >engagement_score</th>
#       <td id="T_a8deb_row2_col0" class="data row2 col0" >-0.078337</td>
#       <td id="T_a8deb_row2_col1" class="data row2 col1" >0.216614</td>
#       <td id="T_a8deb_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a8deb_row2_col3" class="data row2 col3" >0.438577</td>
#       <td id="T_a8deb_row2_col4" class="data row2 col4" >-0.008746</td>
#       <td id="T_a8deb_row2_col5" class="data row2 col5" >-0.159343</td>
#       <td id="T_a8deb_row2_col6" class="data row2 col6" >0.051367</td>
#       <td id="T_a8deb_row2_col7" class="data row2 col7" >0.011241</td>
#       <td id="T_a8deb_row2_col8" class="data row2 col8" >0.013696</td>
#       <td id="T_a8deb_row2_col9" class="data row2 col9" >0.006148</td>
#     </tr>
#     <tr>
#       <th id="T_a8deb_level0_row3" class="row_heading level0 row3" >tenure</th>
#       <td id="T_a8deb_row3_col0" class="data row3 col0" >0.029178</td>
#       <td id="T_a8deb_row3_col1" class="data row3 col1" >0.199276</td>
#       <td id="T_a8deb_row3_col2" class="data row3 col2" >0.438577</td>
#       <td id="T_a8deb_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_a8deb_row3_col4" class="data row3 col4" >-0.009208</td>
#       <td id="T_a8deb_row3_col5" class="data row3 col5" >-0.043800</td>
#       <td id="T_a8deb_row3_col6" class="data row3 col6" >-0.029627</td>
#       <td id="T_a8deb_row3_col7" class="data row3 col7" >0.053055</td>
#       <td id="T_a8deb_row3_col8" class="data row3 col8" >-0.052548</td>
#       <td id="T_a8deb_row3_col9" class="data row3 col9" >0.036704</td>
#     </tr>
#     <tr>
#       <th id="T_a8deb_level0_row4" class="row_heading level0 row4" >n_of_reports</th>
#       <td id="T_a8deb_row4_col0" class="data row4 col0" >0.053808</td>

# %%
model = smf.ols("engagement_score ~ intervention",
        data=df).fit()
print("ATE:", model.params["intervention"])
print("95% CI:", model.conf_int().loc["intervention", :].values.T)
# Out:
# ATE: 0.43459886274141496
# 95% CI: [0.39693035 0.47226738]

# %%
import statsmodels.formula.api as smf

smf.ols("engagement_score ~ intervention",
        data=df).fit().summary().tables[1]
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
mtl0cire05.plot_engagement_vs_intervention(df)

# %%
# Density curves comparing distributions
mtl0cire05.plot_engagement_density_by_intervention(df)

# %%
# TODO(gp): Switch to pdfs
mtl0cire05.plot_engagement_vs_intervention_by_department(df)

# %%
#mtl0cire05.plot_all_variables_vs_intervention(df)

# %%
mtl0cire05.plot_all_variables_density_by_intervention(df)

# %%
# To reduce this bias, you can adjust for the covariates you have in your data.
model = smf.ols("""
engagement_score ~ intervention
    + tenure + last_engagement_score + department_score
    + n_of_reports + C(gender) + C(role)""", data=df).fit()

print("ATE:", model.params["intervention"])
print("95% CI:", model.conf_int().loc["intervention", :].values.T)
# Out:
# ATE: 0.26779085766768607
# 95% CI: [0.23357751 0.30200421]

# %%
model = smf.ols("engagement_score ~ intervention",
        data=df).fit()
print("ATE:", model.params["intervention"])
print("95% CI:", model.conf_int().loc["intervention", :].values.T)
# Out:
# ATE: 0.43459886274141496
# 95% CI: [0.39693035 0.47226738]

# %%
- The effect estimate here is considerably smaller than the one you got earlier.
- This is some indication of positive bias, which means that managers whose
  employees were already more engaged are more likely to have participated in the
  manager training program

# %%
## Propensity score

# %%
ps_model = smf.logit("""
intervention ~ 
    tenure + last_engagement_score + department_score
    + C(n_of_reports) + C(gender) + C(role)""", data=df).fit(disp=0)

data_ps = df.copy()
data_ps["propensity_score"] = ps_model.predict(df)

data_ps[["intervention", "engagement_score", "propensity_score"]].head()
# Out:
#    intervention  engagement_score  propensity_score
# 0             1          0.277359          0.596106
# 1             1         -0.449646          0.391138
# 2             1          0.769703          0.602578
# 3             1         -0.121763          0.580990
# 4             1          1.526147          0.619976

# %%
# Estimate using propensity score as confounder / covariate.
model = smf.ols("""
    engagement_score ~ intervention + propensity_score
    """, data=data_ps).fit()
print(model.params["intervention"])
# Out:
# 0.26331267490277155

# %%
## Propensity score matching

# %%
from sklearn.neighbors import KNeighborsRegressor
# Perform 1-nearest neighbor propensity score matching.
predicted = mtl0cire05.propensity_score_matching(data_ps)
predicted.head()

# %%
# Calculate average treatment effect from propensity score matching.
hat_ATE = mtl0cire05.calculate_psm_ate(predicted)
print(f"ATE (Propensity Score Matching): {hat_ATE:.4f}")

# %%
# Plot inverse probability of treatment weighting results.
mtl0cire05.plot_iptw(data_ps)
